# %%
import numpy as np
import pandas as pd
import xlrd
import matplotlib.pyplot as plt

# %%
data_path = 'E:\\Documents\\Time Series\\Project\\data\\data_VNIdex_2021_2023.csv'

# %%
data_raw = pd.read_csv(data_path)

# %%
data_raw
# Out:
#            Date     Close      Open      High       Low   Volume Change%
# 0    2023-12-25  1,117.66  1,103.06  1,118.31  1,103.06  658.54K   1.32%
# 1    2023-12-22  1,103.06  1,102.43  1,104.65  1,099.32  558.03K   0.06%
# 2    2023-12-21  1,102.43  1,100.76  1,102.43  1,094.47  521.00K   0.15%
# 3    2023-12-20  1,100.76  1,096.30  1,102.27  1,093.38  598.21K   0.41%
# 4    2023-12-19  1,096.30  1,091.88  1,096.30  1,082.29  649.91K   0.40%
# ..          ...       ...       ...       ...       ...      ...     ...
# 739  2021-01-08  1,167.69  1,164.10  1,176.33  1,160.48  808.31K   0.97%
# 740  2021-01-07  1,156.49  1,147.26  1,156.49  1,143.44  763.74K   1.16%
# 741  2021-01-06  1,143.21  1,139.12  1,152.85  1,133.70  790.45K   0.94%
# 742  2021-01-05  1,132.55  1,116.96  1,134.45  1,116.49  763.43K   1.08%
# 743  2021-01-04  1,120.47  1,113.77  1,126.43  1,113.59  764.04K   1.50%
#
# [744 rows x 7 columns]

# %%
data_raw['Date'] = pd.to_datetime(data_raw['Date'], format='%Y/%m/%d')

# %%
# data.to_csv('data_VNIdex_2021_2023.csv', index=False)

# %%
data_raw
# Out:
#           Date     Close      Open      High       Low   Volume Change%
# 0   2023-12-25  1,117.66  1,103.06  1,118.31  1,103.06  658.54K   1.32%
# 1   2023-12-22  1,103.06  1,102.43  1,104.65  1,099.32  558.03K   0.06%
# 2   2023-12-21  1,102.43  1,100.76  1,102.43  1,094.47  521.00K   0.15%
# 3   2023-12-20  1,100.76  1,096.30  1,102.27  1,093.38  598.21K   0.41%
# 4   2023-12-19  1,096.30  1,091.88  1,096.30  1,082.29  649.91K   0.40%
# ..         ...       ...       ...       ...       ...      ...     ...
# 739 2021-01-08  1,167.69  1,164.10  1,176.33  1,160.48  808.31K   0.97%
# 740 2021-01-07  1,156.49  1,147.26  1,156.49  1,143.44  763.74K   1.16%
# 741 2021-01-06  1,143.21  1,139.12  1,152.85  1,133.70  790.45K   0.94%
# 742 2021-01-05  1,132.55  1,116.96  1,134.45  1,116.49  763.43K   1.08%
# 743 2021-01-04  1,120.47  1,113.77  1,126.43  1,113.59  764.04K   1.50%
#
# [744 rows x 7 columns]

# %%
data = data_raw[['Date', 'Close']]

# %%
data
# Out:
#           Date     Close
# 0   2023-12-25  1,117.66
# 1   2023-12-22  1,103.06
# 2   2023-12-21  1,102.43
# 3   2023-12-20  1,100.76
# 4   2023-12-19  1,096.30
# ..         ...       ...
# 739 2021-01-08  1,167.69
# 740 2021-01-07  1,156.49
# 741 2021-01-06  1,143.21
# 742 2021-01-05  1,132.55
# 743 2021-01-04  1,120.47
#
# [744 rows x 2 columns]

# %%
# data.set_index('Date', inplace=True)
data = data.asfreq("D")

# %%
data
# Out:
#                Close
# Date
# 2021-01-04  1,120.47
# 2021-01-05  1,132.55
# 2021-01-06  1,143.21
# 2021-01-07  1,156.49
# 2021-01-08  1,167.69
# ...              ...
# 2023-12-21  1,102.43
# 2023-12-22  1,103.06
# 2023-12-23       NaN
# 2023-12-24       NaN
# 2023-12-25  1,117.66
#
# [1086 rows x 1 columns]

# %%
data= data.dropna()

# %%
data
# Out:
#                Close
# Date
# 2021-01-04  1,120.47
# 2021-01-05  1,132.55
# 2021-01-06  1,143.21
# 2021-01-07  1,156.49
# 2021-01-08  1,167.69
# ...              ...
# 2023-12-19  1,096.30
# 2023-12-20  1,100.76
# 2023-12-21  1,102.43
# 2023-12-22  1,103.06
# 2023-12-25  1,117.66
#
# [744 rows x 1 columns]

# %%
data['Close'] = data['Close'].str.replace(',', '').astype(float)
# Out:
# C:\Users\COMPUTER\AppData\Local\Temp/ipykernel_18720/745001292.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Close'] = data['Close'].str.replace(',', '').astype(float)

# %%
# Plot 'Close' column
plt.figure(figsize=(10, 6))
plt.plot(data.index, data['Close'], marker='o', linestyle='-')
plt.title('Close Prices Over Time')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
data.plot()
plt.show()
